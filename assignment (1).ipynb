# %% [markdown]
# # "My Jupyter Notebook on IBM Watson Studio"

# %% [markdown]
# __Arti nitnaware__

# %% [markdown]
# data scientist

# %% [markdown]
# _I am interested in data science beacause I enjoy problem solving and I am passionate about data._

# %% [markdown]
# ### print (4+5)/9

# %%
(4+5)/9
# Out:
# 1.0

# %% [markdown]
# * first name
# * second name
# * third name
#
# 1. abc numbered item
# 2. xyz numbered item
# 3. lmn numbered item
#
#
# ![15_a.png](attachment:15_a.png)
